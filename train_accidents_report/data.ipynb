# %% [markdown]
# # Displaying train accidents data from the CSV file
#
# First, install pandas library

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\jazzo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# Then, import pandas and read data from the CSV source file.

# %%
# Import pandas library
import pandas as read_file

# Read from the specific CSV file
train_data = read_file.read_csv('2022_train_accidents_data.csv')

# Display data
display(train_data)
# Out:
#     IYR   IMO   RAILROAD  INCDTNO  IYR2  IMO2       RR2  INCDTNO2  IYR3  IMO3  \
# 22   12   ARR    2022195      NaN   NaN   NaN       NaN      22.0  12.0   ARR
# 22    4  BNSF  CH0422117      NaN   NaN   NaN       NaN      22.0   4.0   ADM
# 22    1  BNSF  CA0122115      NaN   NaN   NaN       NaN      22.0   1.0  XJPC
# 22    1  BNSF  CA0122115      NaN   NaN   NaN       NaN      22.0   1.0  XJPC
# 22    5   BLF   20220523      NaN   NaN   NaN       NaN      22.0   5.0   FEC
# ..  ...   ...        ...      ...   ...   ...       ...       ...   ...   ...
# 22    1  BNSF  PR0122101      NaN   NaN   NaN       NaN      22.0   1.0  BNSF
# 22   11    UP  1122RM012      NaN   NaN   NaN       NaN      22.0  11.0    UP
# 22    5    UP  0522RM001      NaN   NaN   NaN       NaN      22.0   5.0    UP
# 22    5    UP  0522RM003      NaN   NaN   NaN       NaN      22.0   5.0    UP
# 22    5    UP  0522GP007     22.0   5.0  XWPP  INDUSTRY      22.0   5.0  XWPP
#
# ...
